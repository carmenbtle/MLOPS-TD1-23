# %%
import pandas as pd
import os

# %%
df1 = pd.read_csv ("//ad.univ-lille.fr/Etudiants/Homedir3/287058/Documents/M2/MLOPS/MLOPS-TD1-23/donnéestd/restaurant_1_week_002.csv")

# %%
df1.head()
# Out:
#    Order Number           Order Date      Item Name  Quantity  Product Price  \
# 0          1388  2015-01-10 20:12:00  Onion Chutney         1           0.50
# 1          1388  2015-01-10 20:12:00     Mint Sauce         1           0.50
# 2          1388  2015-01-10 20:12:00    Lime Pickle         1           0.50
# 3          1388  2015-01-10 20:12:00        Paratha         1           2.95
# 4          1387  2015-01-10 16:55:00    Onion Bhaji         1           3.95
#
#    Total products
# 0               6
# 1               6
# 2               6
# 3               6
# 4               1

# %%
df2 = pd.read_csv ("//ad.univ-lille.fr/Etudiants/Homedir3/287058/Documents/M2/MLOPS/MLOPS-TD1-23/donnéestd/restaurant_1_week_007.csv")

# %%
df2.head()
# Out:
#    Order Number           Order Date      Item Name  Quantity  Product Price  \
# 0          1397  2015-02-10 14:38:00  Spicy Papadum         1           0.80
# 1          1403  2015-02-10 17:29:00        Paratha         1           2.95
# 2          1403  2015-02-10 17:29:00   Coke 1.5 ltr         1           2.95
# 3          1403  2015-02-10 17:29:00     Lemon Rice         1           3.95
# 4          1402  2015-02-10 16:39:00    Onion Bhaji         1           3.95
#
#    Total products
# 0               5
# 1               9
# 2               9
# 3               9
# 4               6

# %%
data_dir = '//ad.univ-lille.fr/Etudiants/Homedir3/287058/Documents/M2/MLOPS/MLOPS-TD1-23'
prefix = "restaurant_1"
start_week = 108
end_week = 110

df = pd.DataFrame()
for i in range (start_week, end_week+1):
    file_path = os.path.join(data_dir, "donnéestd" , f'{prefix}_week_{i}.csv')
    if os.path.isfile(file_path):
        batch = pd.read_csv(file_path)
        df = pd.concat([df, batch], sort = True)
df.head()
# Out:
#        Item Name           Order Date  Order Number  Product Price  Quantity  \
# 0  Mango Chutney  2017-01-28 19:14:00          4416            0.5         3
# 1  Mango Chutney  2017-01-28 18:41:00          4414            0.5         1
# 2     Mint Sauce  2017-01-28 18:41:00          4414            0.5         1
# 3  Mango Chutney  2017-01-28 18:28:00          4413            0.5         1
# 4  Mango Chutney  2017-01-28 12:32:00          4402            0.5         1
#
#    Total products
# 0               4
# 1              13
# 2              13
# 3               6
# 4              10

# %%
df
# Out:
#                      Item Name           Order Date  Order Number  \
# 0                Mango Chutney  2017-01-28 19:14:00          4416
# 1                Mango Chutney  2017-01-28 18:41:00          4414
# 2                   Mint Sauce  2017-01-28 18:41:00          4414
# 3                Mango Chutney  2017-01-28 18:28:00          4413
# 4                Mango Chutney  2017-01-28 12:32:00          4402
# ..                         ...                  ...           ...
# 481       Tandoori Mixed Grill  2017-02-07 13:09:00          5900
# 482  Hazary Lamb Chilli Garlic  2017-02-10 17:38:00          6936
# 483        King Prawn Shaslick  2017-02-09 17:35:00          6590
# 484                      Bhuna  2017-02-08 18:16:00          6249
# 485        House Red wine 75cl  2017-02-10 17:38:00          6936
#
#      Product Price  Quantity  Total products
# 0             0.50         3               4
# 1             0.50         1              13
# ...
